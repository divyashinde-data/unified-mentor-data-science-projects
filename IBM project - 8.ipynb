# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\Divya\\Downloads\\WA_Fn-UseC_-HR-Employee-Attrition.csv")
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
for col in ['Attrition','Department','JobRole','Gender','BusinessTravel',
            'MaritalStatus','EducationField','OverTime','WorkLifeBalance']:
    print(col, "→", df[col].nunique(), "unique values")
    print(df[col].unique())
    print("-"*40)
# Out:
# Attrition → 2 unique values
# ['Yes' 'No']
# ----------------------------------------
# Department → 3 unique values
# ['Sales' 'Research & Development' 'Human Resources']
# ----------------------------------------
# JobRole → 9 unique values
# ['Sales Executive' 'Research Scientist' 'Laboratory Technician'
#  'Manufacturing Director' 'Healthcare Representative' 'Manager'
#  'Sales Representative' 'Research Director' 'Human Resources']
# ----------------------------------------
# Gender → 2 unique values
# ['Female' 'Male']
# ----------------------------------------
# BusinessTravel → 3 unique values
# ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# ----------------------------------------
# MaritalStatus → 3 unique values
# ['Single' 'Married' 'Divorced']
# ----------------------------------------
# EducationField → 6 unique values
# ['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']
# ----------------------------------------
# ...

# %%
df['Attrition'].value_counts()
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()
df.shape
# Out:
# (1470, 35)

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
num_cols = df.select_dtypes(include=['int64', 'float64']).columns
df[num_cols] = df[num_cols].fillna(df[num_cols].median())

cat_cols = df.select_dtypes(include=['object']).columns
for col in cat_cols:
    df[col] = df[col].fillna(df[col].mode()[0])

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
df['Attrition'].value_counts().plot(kind='bar')
plt.xlabel('Attrition')
plt.ylabel('Count')
plt.title('Attrition Distribution')
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.hist(df['Age'], bins=20)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution')
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.hist(df['MonthlyIncome'], bins=25)
plt.xlabel('Monthly Income')
plt.ylabel('Frequency')
plt.title('Monthly Income Distribution')
plt.show()

# %%
plt.figure(figsize=(6,4))
df['Education'].value_counts().sort_index().plot(kind='bar')
plt.xlabel('Education Level (1–5)')
plt.ylabel('Count')
plt.title('Education Level Distribution')
plt.show()

# %%
plt.figure(figsize=(6,4))
df['JobSatisfaction'].value_counts().sort_index().plot(kind='bar')
plt.xlabel('Job Satisfaction Level (1–4)')
plt.ylabel('Count')
plt.title('Job Satisfaction Distribution')
plt.show()

# %%
plt.figure(figsize=(6,4))
df.boxplot(column='Age', by='Attrition')
plt.title('Age vs Attrition')
plt.suptitle('')
plt.xlabel('Attrition')
plt.ylabel('Age')
plt.show()

# %%
plt.figure(figsize=(6,4))
df.boxplot(column='MonthlyIncome', by='Attrition')
plt.title('Monthly Income vs Attrition')
plt.suptitle('')
plt.xlabel('Attrition')
plt.ylabel('Monthly Income')
plt.show()

# %%
plt.figure(figsize=(8,4))
df['JobRole'][df['Attrition']=='Yes'].value_counts().plot(kind='bar')
plt.xlabel('Job Role')
plt.ylabel('Attrition Count')
plt.title('Attrition by Job Role')
plt.show()

# %%
plt.figure(figsize=(6,4))
df['WorkLifeBalance'][df['Attrition']=='Yes'].value_counts().sort_index().plot(kind='bar')
plt.xlabel('Work-Life Balance Level (1–4)')
plt.ylabel('Employees Left')
plt.title('Attrition vs Work-Life Balance')
plt.show()

# %%
plt.figure(figsize=(6,4))
df['EnvironmentSatisfaction'][df['Attrition']=='Yes'].value_counts().sort_index().plot(kind='bar')
plt.xlabel('Environment Satisfaction (1–4)')
plt.ylabel('Employees Left')
plt.title('Attrition vs Environment Satisfaction')
plt.show()
